# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:43, 722KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

c = Counter(int_words)
total_count = len(int_words)
train_words = [i for i in int_words if (1 - (np.sqrt(1e-5 / (c[i] / total_count)))) > random.random()]
print(train_words[:10])
# Out:
# [11, 5, 194, 1, 45, 58, 127, 741, 133, 0]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    s = np.random.normal(0,  window_size / 1.5, 1)
    R = int(abs(s[0]))
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx + 1:stop + 1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 8.7885 0.0531 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.6088 0.0502 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.3440 0.0496 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5786 0.0497 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2528 0.0495 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.9273 0.0499 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.6981 0.0496 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.5313 0.0497 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.6078 0.0498 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.5510 0.0504 sec/batch
# Nearest to from: online, popularised, island, soldier, large, that, ever, movie,
# Nearest to is: ann, connection, against, classes, small, caroli, director, arms,
# Nearest to all: council, point, one, display, lack, office, platelets, forested,
# Nearest to during: fanshawe, reference, applied, rear, to, use, increase, planned,
# Nearest to it: body, debate, plane, computing, level, throne, post, restore,
# Nearest to would: the, public, presidential, perform, works, technology, notion, children,
# Nearest to system: moon, fast, labor, mixed, byu, flat, india, a,
# Nearest to united: two, vaccine, towards, presented, bbc, shot, air, writings,
# Nearest to liberal: once, studies, friend, negative, when, shown, hoping, provides,
# Nearest to primarily: requiring, charming, on, toughened, ashamed, per, albums, punjab,
# Nearest to http: collect, yf, stimulate, superstardom, m, graviton, annulment, luiz,
# Nearest to orthodox: com, fleet, refuelled, midday, upswing, international, still, ably,
# Nearest to san: courses, class, clock, derived, bdeac, children, just, backgammon,
# Nearest to ice: tull, cabin, genosha, operations, source, utraquists, kfreebsd, hughes,
# Nearest to assembly: process, continuum, love, chalcolithic, marsyas, passau, meeting, get,
# Nearest to bill: retraction, least, whom, less, road, expressed, intended, ivies,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.4840 0.0520 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.4386 0.0503 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.3661 0.0506 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.3676 0.0510 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.4014 0.0512 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.3726 0.0515 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.3694 0.0518 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.2788 0.0534 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.3525 0.0529 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.2992 0.0538 sec/batch
# Nearest to from: online, island, popularised, provincial, fan, ever, soldier, province,
# Nearest to is: connection, ann, classes, small, against, arms, caroli, director,
# Nearest to all: council, display, point, one, weight, critic, lack, office,
# Nearest to during: rear, fanshawe, reference, applied, to, undertaken, need, figures,
# Nearest to it: plane, body, debate, throne, computing, post, imf, officers,
# Nearest to would: public, the, presidential, perform, wheel, notion, arabic, smith,
# Nearest to system: moon, labor, fast, mixed, conducted, representation, india, flat,
# Nearest to united: two, vaccine, towards, shot, air, bbc, writings, presented,
# Nearest to liberal: friend, negative, studies, when, provides, once, shown, amongst,
# Nearest to primarily: requiring, albums, on, going, per, prove, charming, problem,
# Nearest to http: collect, m, settled, n, yf, stimulate, transit, volumes,
# Nearest to orthodox: fleet, com, midday, international, refuelled, frank, still, ed,
# Nearest to san: clock, courses, class, derived, children, crossed, just, downtown,
# Nearest to ice: source, operations, series, chose, hughes, cabin, genosha, forces,
# Nearest to assembly: biology, process, continuum, chalcolithic, marsyas, meeting, throne, specified,
# Nearest to bill: gallery, retraction, road, expressed, treatise, least, whom, gillis,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.2945 0.0543 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.2706 0.0551 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.2116 0.0551 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.2246 0.0564 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.2570 0.0568 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.2455 0.0562 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.2305 0.0565 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.2612 0.0577 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.2618 0.0572 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.1179 0.0594 sec/batch
# Nearest to from: online, island, provincial, popularised, fan, rivals, province, residents,
# Nearest to is: connection, ann, small, classes, against, arms, director, applies,
# Nearest to all: council, display, point, weight, one, communion, critic, pagan,
# Nearest to during: rear, reference, fanshawe, applied, to, undertaken, os, figures,
# Nearest to it: imf, plane, body, throne, debate, officers, post, jurisdiction,
# Nearest to would: public, commands, perform, wheel, laid, arabic, henri, reserved,
# Nearest to system: labor, moon, fast, behaviour, mixed, conducted, opera, representation,
# Nearest to united: vaccine, two, towards, shot, air, bbc, writings, ammunition,
# Nearest to liberal: friend, when, negative, provides, once, shown, studies, amongst,
# Nearest to primarily: requiring, albums, on, prove, charming, going, stronger, per,
# Nearest to http: collect, m, settled, n, florida, transit, volumes, purchase,
# Nearest to orthodox: fleet, com, still, midday, refuelled, upswing, international, ed,
# Nearest to san: clock, class, courses, derived, children, crossed, span, passages,
# Nearest to ice: source, operations, hughes, chose, series, briefly, victories, small,
# Nearest to assembly: process, continuum, biology, chalcolithic, marsyas, meeting, specified, economics,
# Nearest to bill: gallery, retraction, road, expressed, treatise, films, attitude, less,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.2659 0.0588 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.1823 0.0584 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.2150 0.0588 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.1975 0.0590 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.2071 0.0598 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.1636 0.0595 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.1967 0.0599 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.1900 0.0604 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.1643 0.0605 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.1952 0.0608 sec/batch
# Nearest to from: online, provincial, island, popularised, rivals, fan, ever, fashion,
# Nearest to is: ann, small, connection, classes, nights, arms, applies, finish,
# Nearest to all: council, display, point, communion, weight, one, pagan, lack,
# Nearest to during: rear, applied, reference, fanshawe, harmony, to, undertaken, os,
# Nearest to it: imf, plane, body, debate, throne, officers, this, post,
# Nearest to would: perform, henri, public, wheel, commands, laid, reserved, experiences,
# Nearest to system: behaviour, labor, moon, fast, conducted, mixed, representation, flat,
# Nearest to united: vaccine, two, air, towards, bbc, ammunition, fruit, writings,
# Nearest to liberal: friend, negative, when, provides, studies, recommended, once, file,
# Nearest to primarily: requiring, albums, on, prove, stronger, frequently, problem, charming,
# Nearest to http: collect, m, settled, transit, n, florida, volumes, purchase,
# Nearest to orthodox: fleet, com, upswing, refuelled, still, confined, midday, painter,
# Nearest to san: clock, class, courses, derived, children, span, passages, crossed,
# Nearest to ice: source, operations, chose, hughes, series, paint, victories, briefly,
# Nearest to assembly: continuum, process, chalcolithic, marsyas, biology, udon, dogs, economics,
# Nearest to bill: gallery, retraction, arch, films, federation, geographic, attitude, expressed,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.1649 0.0619 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.1642 0.0616 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.1649 0.0616 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.1817 0.0617 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.1251 0.0623 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.1360 0.0624 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.1133 0.0624 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.1579 0.0627 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.1328 0.0630 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.1296 0.0631 sec/batch
# Nearest to from: online, provincial, island, popularised, rivals, ever, fan, large,
# Nearest to is: connection, ann, small, classes, arms, chemical, means, applies,
# Nearest to all: council, display, point, communion, weight, one, pagan, critic,
# Nearest to during: rear, harmony, undertaken, applied, reference, to, fanshawe, later,
# Nearest to it: imf, plane, body, throne, debate, this, created, level,
# Nearest to would: henri, perform, wheel, reserved, pressures, jewishencyclopedia, children, commands,
# Nearest to system: behaviour, moon, labor, fast, mixed, conducted, flat, comprising,
# Nearest to united: vaccine, two, air, towards, bbc, ammunition, fruit, writings,
# Nearest to liberal: friend, provides, when, recommended, negative, file, once, studies,
# Nearest to primarily: requiring, albums, on, prove, charming, problem, frequently, organs,
# Nearest to http: collect, m, settled, transit, n, florida, volumes, purchase,
# Nearest to orthodox: fleet, com, upswing, confined, painter, midday, still, front,
# Nearest to san: clock, class, courses, derived, span, passages, children, crossed,
# Nearest to ice: source, operations, hughes, chose, series, victories, paint, briefly,
# Nearest to assembly: continuum, udon, marsyas, chalcolithic, dogs, economics, biology, meeting,
# Nearest to bill: gallery, federation, shi, arch, road, films, retraction, matthew,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.1742 0.0642 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.1786 0.0636 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.1594 0.0637 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.1478 0.0643 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.1250 0.0644 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.1509 0.0644 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.1401 0.0647 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.1293 0.0647 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.1404 0.0651 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.1462 0.0650 sec/batch
# Nearest to from: online, provincial, island, popularised, rivals, gathered, fan, ever,
# Nearest to is: connection, small, ann, means, classes, chemical, arms, nights,
# Nearest to all: council, communion, display, weight, one, point, beings, pagan,
# Nearest to during: rear, undertaken, harmony, to, later, applied, fanshawe, reference,
# Nearest to it: imf, plane, body, debate, throne, this, currents, authoritarian,
# Nearest to would: perform, continuation, henri, could, pressures, children, jewishencyclopedia, presidential,
# Nearest to system: behaviour, labor, moon, fast, comprising, flat, mixed, representation,
# Nearest to united: vaccine, air, towards, two, bbc, ammunition, fruit, polymers,
# Nearest to liberal: recommended, friend, studies, provides, religions, when, amongst, negative,
# Nearest to primarily: requiring, albums, charming, on, prove, organs, stronger, axioms,
# Nearest to http: collect, m, n, luke, transit, florida, settled, challenged,
# Nearest to orthodox: fleet, church, painter, upswing, confined, gaim, refuelled, front,
# Nearest to san: clock, class, courses, span, derived, passages, crossed, children,
# Nearest to ice: source, operations, hughes, chose, series, victories, paint, briefly,
# Nearest to assembly: udon, continuum, marsyas, dogs, biology, economics, meeting, drummer,
# Nearest to bill: shi, federation, gallery, films, treatise, arch, retraction, matthew,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.1523 0.0658 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.0766 0.0653 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.0942 0.0655 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.1117 0.0659 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.1707 0.0660 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.1244 0.0658 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.1420 0.0660 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.1520 0.0664 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.1113 0.0661 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.1060 0.0666 sec/batch
# Nearest to from: online, provincial, popularised, rivals, island, fan, gathered, province,
# Nearest to is: small, means, ann, connection, chemical, arms, finish, nights,
# Nearest to all: council, display, communion, weight, beings, one, pagan, point,
# Nearest to during: rear, undertaken, harmony, later, to, fanshawe, figures, applied,
# Nearest to it: imf, body, plane, debate, this, throne, currents, authoritarian,
# Nearest to would: could, continuation, henri, perform, jewishencyclopedia, had, presidential, notion,
# Nearest to system: behaviour, fast, labor, moon, comprising, grammar, mixed, byu,
# Nearest to united: vaccine, air, towards, ammunition, two, bbc, polymers, focus,
# Nearest to liberal: recommended, religions, friend, amongst, provides, hoping, studies, melcher,
# Nearest to primarily: requiring, albums, charming, organs, on, arquette, prove, axioms,
# Nearest to http: collect, m, luke, transit, mp, n, challenged, florida,
# Nearest to orthodox: fleet, church, painter, upswing, gaim, confined, pursue, old,
# Nearest to san: clock, class, courses, span, crossed, derived, passages, natives,
# Nearest to ice: operations, source, hughes, victories, chose, series, genosha, audiences,
# Nearest to assembly: udon, continuum, marsyas, dogs, economics, biology, drummer, meeting,
# Nearest to bill: federation, shi, gallery, films, retraction, arch, road, matthew,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.1312 0.0673 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.1300 0.0668 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.1131 0.0669 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.1195 0.0672 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.1157 0.0671 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.1126 0.0672 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.1429 0.0673 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.1401 0.0675 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.0960 0.0676 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.1170 0.0676 sec/batch
# Nearest to from: provincial, online, popularised, rivals, island, province, autoconfiguration, gathered,
# Nearest to is: means, ann, connection, small, applies, nights, chemical, finish,
# Nearest to all: council, display, one, communion, beings, weight, rubber, point,
# Nearest to during: rear, harmony, undertaken, to, later, fanshawe, through, figures,
# Nearest to it: imf, body, plane, debate, this, throne, authoritarian, currents,
# Nearest to would: could, jewishencyclopedia, continuation, perform, henri, had, children, commands,
# Nearest to system: behaviour, fast, comprising, moon, grammar, labor, representation, byu,
# Nearest to united: vaccine, air, towards, naval, polymers, two, ammunition, underlining,
# Nearest to liberal: recommended, religions, studies, hoping, amongst, friend, melcher, marx,
# Nearest to primarily: requiring, albums, charming, organs, on, arquette, spelled, prove,
# Nearest to http: collect, m, transit, luke, mp, n, florida, stimulate,
# Nearest to orthodox: fleet, church, upswing, painter, confined, gaim, pursue, ypsilanti,
# Nearest to san: clock, class, courses, span, passages, crossed, derived, marie,
# Nearest to ice: operations, source, hughes, chose, victories, genosha, series, assist,
# Nearest to assembly: udon, marsyas, continuum, economics, meeting, drummer, dogs, process,
# Nearest to bill: shi, federation, retraction, gallery, clinton, arch, expressed, films,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.1155 0.0693 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.1210 0.0685 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.1201 0.0678 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.0821 0.0682 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.1287 0.0677 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.1358 0.0679 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.0639 0.0677 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.0924 0.0684 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.1126 0.0685 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.1259 0.0698 sec/batch
# Nearest to from: online, provincial, island, popularised, rivals, autoconfiguration, province, departments,
# Nearest to is: means, connection, ann, small, nights, finish, chemical, applies,
# Nearest to all: council, display, communion, one, beings, weight, point, rubber,
# Nearest to during: rear, harmony, undertaken, later, fanshawe, reign, to, figures,
# Nearest to it: imf, debate, body, this, plane, currents, throne, authoritarian,
# Nearest to would: could, perform, jewishencyclopedia, continuation, henri, had, children, presidential,
# Nearest to system: behaviour, comprising, fast, representation, labor, grammar, byu, moon,
# Nearest to united: vaccine, towards, air, polymers, naval, highland, focus, ammunition,
# Nearest to liberal: religions, recommended, hoping, julia, fjords, studies, friend, amongst,
# Nearest to primarily: requiring, charming, albums, organs, arquette, on, prove, axioms,
# Nearest to http: collect, luke, transit, org, m, mp, bsd, n,
# Nearest to orthodox: fleet, church, upswing, gaim, painter, ypsilanti, confined, pursue,
# Nearest to san: clock, class, courses, span, derived, passages, crossed, marie,
# Nearest to ice: operations, hughes, source, mistake, chose, genosha, victories, assist,
# Nearest to assembly: udon, marsyas, dogs, continuum, process, meeting, drummer, economics,
# Nearest to bill: federation, shi, retraction, arch, clinton, gallery, films, expressed,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 3.7318 0.0725 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 3.9718 0.0692 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 3.9128 0.0686 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 3.9963 0.0688 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.0740 0.0686 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.0614 0.0690 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.1222 0.0702 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.0976 0.0691 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.1073 0.0697 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.1029 0.0694 sec/batch
# Nearest to from: online, popularised, provincial, island, rivals, autoconfiguration, subgroup, gathered,
# Nearest to is: means, connection, small, ann, nights, applies, finish, resort,
# Nearest to all: council, display, beings, one, communion, weight, rubber, point,
# Nearest to during: rear, harmony, undertaken, figures, later, fanshawe, morrison, admission,
# Nearest to it: imf, body, debate, plane, this, authoritarian, currents, throne,
# Nearest to would: could, jewishencyclopedia, perform, continuation, had, presidential, children, works,
# Nearest to system: behaviour, labor, fast, representation, comprising, kurdish, byu, grammar,
# Nearest to united: vaccine, air, polymers, highland, two, ammunition, towards, naval,
# Nearest to liberal: religions, recommended, julia, studies, fjords, amongst, hoping, melcher,
# Nearest to primarily: requiring, albums, charming, arquette, organs, on, prove, axioms,
# Nearest to http: collect, org, com, transit, rag, mp, bsd, m,
# Nearest to orthodox: fleet, church, gaim, painter, upswing, ypsilanti, confined, pursue,
# Nearest to san: class, clock, courses, span, crossed, derived, pl, electrophoresis,
# Nearest to ice: operations, hughes, mistake, source, genosha, chose, victories, tull,
# Nearest to assembly: udon, marsyas, continuum, dogs, favourite, economics, process, meeting,
# Nearest to bill: federation, shi, arch, clinton, films, retraction, gallery, hefner,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.1305 0.0700 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.0380 0.0694 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.1192 0.0695 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.1101 0.0691 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.0865 0.0692 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.0933 0.0697 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.1262 0.0693 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.1101 0.0695 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.1200 0.0697 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.0171 0.0694 sec/batch
# Nearest to from: online, popularised, provincial, island, rivals, autoconfiguration, doubted, georgia,
# Nearest to is: means, ann, small, finish, connection, roughly, nights, terrorist,
# Nearest to all: council, display, one, beings, communion, weight, wet, rubber,
# Nearest to during: rear, later, harmony, undertaken, fanshawe, figures, quickly, morrison,
# Nearest to it: body, authoritarian, imf, debate, this, plane, currents, created,
# Nearest to would: could, perform, jewishencyclopedia, continuation, had, presidential, works, merger,
# Nearest to system: behaviour, labor, representation, byu, comprising, fast, kurdish, grammar,
# Nearest to united: vaccine, two, air, polymers, highland, ammunition, towards, wales,
# Nearest to liberal: julia, religions, recommended, hoping, marx, fjords, arts, studies,
# Nearest to primarily: requiring, charming, arquette, organs, on, generally, albums, ashamed,
# Nearest to http: collect, org, rag, transit, com, external, mp, annulment,
# Nearest to orthodox: fleet, church, gaim, painter, upswing, ypsilanti, catholic, confined,
# Nearest to san: clock, class, courses, span, crossed, pl, electrophoresis, kalarippayattu,
# Nearest to ice: operations, mistake, source, hughes, genosha, chose, tull, cabin,
# Nearest to assembly: udon, marsyas, drummer, dogs, economics, meeting, favourite, choo,
# Nearest to bill: federation, shi, arch, films, clinton, hefner, retraction, gallery,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.0279 0.0702 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.0691 0.0744 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 3.9883 0.0751 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.0634 0.0698 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.1226 0.0701 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.0985 0.0702 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 3.9887 0.0700 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.0467 0.0698 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.0545 0.0700 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.1062 0.0705 sec/batch
# Nearest to from: online, popularised, provincial, island, rivals, autoconfiguration, doubted, georgia,
# Nearest to is: means, ann, small, connection, roughly, finish, superheroic, nights,
# Nearest to all: council, beings, communion, display, weight, one, wet, point,
# Nearest to during: rear, undertaken, later, harmony, quickly, figures, fanshawe, admission,
# Nearest to it: body, imf, authoritarian, this, debate, currents, plane, labienus,
# Nearest to would: could, perform, jewishencyclopedia, works, continuation, had, will, presidential,
# Nearest to system: behaviour, fast, representation, comprising, labor, byu, grammar, kurdish,
# Nearest to united: vaccine, polymers, air, highland, wales, towards, navy, cassiodorus,
# Nearest to liberal: religions, julia, recommended, fjords, hoping, studies, arts, amongst,
# Nearest to primarily: requiring, charming, organs, arquette, albums, on, generally, ashamed,
# Nearest to http: collect, org, transit, com, rag, external, bsd, stimulate,
# Nearest to orthodox: church, fleet, gaim, catholic, painter, upswing, ypsilanti, confined,
# Nearest to san: class, clock, courses, span, crossed, pl, electrophoresis, kalarippayattu,
# Nearest to ice: operations, mistake, genosha, source, tull, chose, hughes, arkwright,
# Nearest to assembly: udon, marsyas, economics, dogs, passau, process, favourite, unbeatable,
# Nearest to bill: federation, shi, clinton, arch, films, actor, hefner, gallery,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.1137 0.0338 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.1060 0.0698 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.0896 0.0701 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.1084 0.0710 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.0289 0.0702 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.0575 0.0698 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.0372 0.0700 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 3.9380 0.0703 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 3.9933 0.0704 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.1037 0.0703 sec/batch
# Nearest to from: online, popularised, island, provincial, rivals, georgia, autoconfiguration, libya,
# Nearest to is: means, roughly, small, superheroic, ann, resort, survival, connection,
# Nearest to all: council, beings, display, communion, one, weight, rubber, critic,
# Nearest to during: later, rear, harmony, fanshawe, figures, quickly, undertaken, reign,
# Nearest to it: body, imf, this, authoritarian, currents, debate, plane, labienus,
# Nearest to would: could, perform, jewishencyclopedia, will, continuation, must, had, should,
# Nearest to system: behaviour, representation, labor, fast, comprising, byu, kurdish, sefer,
# Nearest to united: vaccine, polymers, highland, wales, two, presidential, navy, dartmouth,
# Nearest to liberal: fjords, religions, recommended, julia, hoping, arts, amongst, marx,
# Nearest to primarily: requiring, charming, albums, organs, arquette, generally, on, ashamed,
# Nearest to http: collect, com, org, transit, www, external, bsd, rag,
# Nearest to orthodox: church, fleet, painter, gaim, catholic, ypsilanti, upswing, confined,
# Nearest to san: class, clock, courses, span, electrophoresis, kalarippayattu, crossed, pl,
# Nearest to ice: operations, mistake, genosha, source, tull, hughes, arkwright, apologize,
# Nearest to assembly: udon, marsyas, dogs, passau, process, economics, qur, continuum,
# Nearest to bill: federation, clinton, shi, films, arch, actor, ivies, hefner,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.0678 0.0710 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.0562 0.0706 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.0436 0.0703 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.0414 0.0707 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.1068 0.0706 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.0751 0.0704 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.0991 0.0702 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.0636 0.0706 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.0696 0.0710 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.0847 0.0706 sec/batch
# Nearest to from: online, popularised, provincial, island, rivals, autoconfiguration, libya, georgia,
# Nearest to is: means, ann, superheroic, roughly, small, nights, connection, resort,
# Nearest to all: council, beings, display, communion, one, weight, rubber, correlate,
# Nearest to during: harmony, rear, later, fanshawe, reign, figures, quickly, undertaken,
# Nearest to it: authoritarian, this, imf, debate, body, labienus, currents, plane,
# Nearest to would: could, jewishencyclopedia, perform, will, must, presidential, continuation, had,
# Nearest to system: representation, behaviour, fast, comprising, byu, labor, kurdish, sefer,
# Nearest to united: vaccine, polymers, air, highland, wales, two, cassiodorus, karachi,
# Nearest to liberal: julia, recommended, fjords, amongst, religions, republican, arts, hoping,
# Nearest to primarily: charming, requiring, arquette, albums, organs, ashamed, expanses, fathoms,
# Nearest to http: collect, org, com, transit, rag, www, external, links,
# Nearest to orthodox: church, fleet, catholic, painter, gaim, protestant, ypsilanti, upswing,
# Nearest to san: class, courses, kalarippayattu, span, electrophoresis, pl, clock, crossed,
# Nearest to ice: operations, mistake, genosha, tull, source, arkwright, architectures, apologize,
# Nearest to assembly: udon, marsyas, process, dogs, passau, choo, drummer, unbeatable,
# Nearest to bill: federation, clinton, shi, films, arch, longitude, actor, expressed,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.0786 0.0712 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.0892 0.0705 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.0820 0.0707 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.0660 0.0712 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.0740 0.0737 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.1018 0.0723 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.0738 0.0725 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.0867 0.0713 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.0950 0.0713 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.0445 0.0717 sec/batch
# Nearest to from: online, popularised, provincial, island, rivals, autoconfiguration, berets, libya,
# Nearest to is: means, superheroic, ann, nights, roughly, resort, transcription, applies,
# Nearest to all: council, beings, display, communion, correlate, voir, one, including,
# Nearest to during: harmony, rear, fanshawe, figures, later, battles, undertaken, reign,
# Nearest to it: authoritarian, this, imf, debate, body, plane, labienus, smooth,
# Nearest to would: could, will, jewishencyclopedia, perform, must, works, presidential, had,
# Nearest to system: representation, comprising, labor, byu, fast, behaviour, kurdish, sefer,
# Nearest to united: vaccine, polymers, wales, air, highland, karachi, cassiodorus, underlining,
# Nearest to liberal: recommended, republican, julia, fjords, parties, arts, support, alliance,
# Nearest to primarily: charming, arquette, requiring, ashamed, organs, albums, on, expanses,
# Nearest to http: collect, org, com, transit, rag, external, www, stimulate,
# Nearest to orthodox: church, catholic, fleet, painter, gaim, protestant, ypsilanti, upswing,
# Nearest to san: class, kalarippayattu, courses, span, electrophoresis, pl, clock, hollows,
# Nearest to ice: operations, mistake, genosha, tull, arkwright, source, apologize, architectures,
# Nearest to assembly: udon, marsyas, process, passau, choo, judicial, lucien, meeting,
# Nearest to bill: federation, clinton, shi, actor, films, longitude, operas, expressed,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.0360 0.0718 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.1104 0.0741 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.0627 0.0712 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.0717 0.0711 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.0825 0.0746 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.0849 0.0749 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.0287 0.0727 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.0874 0.0732 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.0791 0.0730 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.0876 0.0730 sec/batch
# Nearest to from: online, popularised, provincial, autoconfiguration, island, rivals, doubted, berets,
# Nearest to is: means, superheroic, ann, nights, roughly, applies, resort, transcription,
# Nearest to all: council, beings, communion, display, correlate, voir, critic, kang,
# Nearest to during: harmony, fanshawe, later, rear, battles, quickly, figures, reign,
# Nearest to it: this, authoritarian, imf, body, debate, plane, labienus, currents,
# Nearest to would: could, jewishencyclopedia, will, perform, must, should, works, had,
# Nearest to system: representation, byu, behaviour, comprising, fast, sefer, kurdish, labor,
# Nearest to united: vaccine, polymers, wales, highland, air, cassiodorus, karachi, undecidability,
# Nearest to liberal: republican, support, parties, fjords, alliance, recommended, amongst, spreading,
# Nearest to primarily: charming, arquette, generally, albums, organs, on, requiring, ashamed,
# Nearest to http: collect, org, com, rag, transit, stimulate, xl, external,
# Nearest to orthodox: church, catholic, fleet, painter, protestant, gaim, ypsilanti, emergent,
# Nearest to san: class, span, kalarippayattu, pl, courses, electrophoresis, clock, california,
# Nearest to ice: operations, mistake, tull, apologize, off, arkwright, vasily, genosha,
# Nearest to assembly: udon, marsyas, passau, judicial, choo, lucien, unbeatable, receivers,
# Nearest to bill: clinton, shi, federation, actor, films, longitude, arch, operas,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.0854 0.0737 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.0655 0.0732 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.0887 0.0732 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.0956 0.0730 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.0542 0.0731 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.0560 0.0737 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.0203 0.0734 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.0696 0.0730 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.0557 0.0732 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.0458 0.0734 sec/batch
# Nearest to from: online, popularised, provincial, autoconfiguration, rivals, island, doubted, foo,
# Nearest to is: means, superheroic, ann, nights, roughly, applies, transcription, avianca,
# Nearest to all: council, beings, communion, display, correlate, weight, every, orbits,
# Nearest to during: later, rear, fanshawe, quickly, harmony, battles, reign, figures,
# Nearest to it: this, authoritarian, imf, labienus, debate, body, currents, plane,
# Nearest to would: could, will, jewishencyclopedia, should, had, must, works, perform,
# Nearest to system: representation, comprising, behaviour, byu, fast, sefer, kurdish, watterson,
# Nearest to united: vaccine, polymers, highland, cassiodorus, wales, undecidability, air, presidential,
# Nearest to liberal: republican, parties, fjords, recommended, support, marx, leaders, amongst,
# Nearest to primarily: charming, generally, albums, arquette, ashamed, fathoms, on, requiring,
# Nearest to http: collect, org, com, rag, transit, stimulate, annulment, external,
# Nearest to orthodox: church, catholic, fleet, painter, protestant, gaim, ypsilanti, emergent,
# Nearest to san: class, kalarippayattu, span, california, courses, electrophoresis, pl, clock,
# Nearest to ice: operations, mistake, tull, architectures, apologize, genosha, arkwright, off,
# Nearest to assembly: udon, marsyas, judicial, passau, choo, receivers, process, lucien,
# Nearest to bill: federation, clinton, actor, shi, longitude, films, convenience, chose,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.0985 0.0740 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.0824 0.0733 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.0514 0.0729 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.1014 0.0735 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.0436 0.0730 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.0645 0.0733 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.0784 0.0732 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.0477 0.0735 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.0637 0.0730 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.0808 0.0729 sec/batch
# Nearest to from: online, popularised, provincial, autoconfiguration, island, rivals, doubted, name,
# Nearest to is: means, superheroic, ann, applies, transcription, nights, avianca, was,
# Nearest to all: council, beings, communion, display, voir, correlate, kang, ring,
# Nearest to during: harmony, later, rear, quickly, fanshawe, reign, battles, athene,
# Nearest to it: this, authoritarian, imf, debate, labienus, body, throne, currents,
# Nearest to would: could, will, should, jewishencyclopedia, might, had, must, works,
# Nearest to system: representation, comprising, byu, behaviour, sefer, labor, fast, kurdish,
# Nearest to united: vaccine, polymers, highland, cassiodorus, wales, air, undecidability, karachi,
# Nearest to liberal: republican, parties, alliance, fjords, recommended, support, arts, continue,
# Nearest to primarily: charming, arquette, generally, albums, ashamed, on, fathoms, organs,
# Nearest to http: collect, org, com, rag, discriminate, mp, xl, www,
# Nearest to orthodox: church, catholic, protestant, painter, fleet, gaim, ypsilanti, churches,
# Nearest to san: class, kalarippayattu, span, electrophoresis, california, pl, hollows, clock,
# Nearest to ice: operations, mistake, tull, architectures, arkwright, apologize, off, genosha,
# Nearest to assembly: udon, marsyas, judicial, passau, process, choo, lucien, receivers,
# Nearest to bill: clinton, federation, shi, actor, films, longitude, convenience, operas,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.0616 0.0741 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.0408 0.0732 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.0215 0.0733 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.0592 0.0733 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.0350 0.0732 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.0912 0.0733 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.0500 0.0736 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.1042 0.0734 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.0221 0.0731 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.1026 0.0732 sec/batch
# Nearest to from: popularised, online, provincial, rivals, island, autoconfiguration, berets, gv,
# Nearest to is: means, superheroic, was, ann, applies, roughly, resort, transcription,
# Nearest to all: council, beings, communion, correlate, voir, kang, every, display,
# Nearest to during: harmony, later, battles, rear, athene, fanshawe, quickly, figures,
# Nearest to it: authoritarian, this, imf, labienus, debate, body, somalis, smooth,
# Nearest to would: could, will, might, should, jewishencyclopedia, works, must, had,
# Nearest to system: representation, comprising, byu, sefer, behaviour, systems, kurdish, watterson,
# Nearest to united: vaccine, polymers, air, cassiodorus, undecidability, highland, navy, karachi,
# Nearest to liberal: republican, parties, alliance, fjords, support, recommended, marx, roar,
# Nearest to primarily: charming, arquette, generally, ashamed, fathoms, albums, expanses, on,
# Nearest to http: collect, org, com, rag, stimulate, www, mp, xl,
# Nearest to orthodox: church, catholic, protestant, painter, fleet, gaim, churches, ypsilanti,
# Nearest to san: class, span, kalarippayattu, electrophoresis, california, clock, pl, hollows,
# Nearest to ice: operations, off, architectures, mistake, tull, vasily, arkwright, apologize,
# Nearest to assembly: udon, marsyas, judicial, passau, lucien, receivers, choo, process,
# Nearest to bill: clinton, shi, federation, actor, longitude, films, chose, convenience,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.0347 0.0740 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.0689 0.0732 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.0488 0.0733 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.0761 0.0733 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.0697 0.0737 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.0557 0.0738 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.0883 0.0735 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.0794 0.0735 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.0642 0.0734 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.0739 0.0736 sec/batch
# Nearest to from: popularised, online, provincial, autoconfiguration, rivals, georgia, berets, gv,
# Nearest to is: means, superheroic, ann, was, applies, avianca, resort, finish,
# Nearest to all: council, beings, communion, correlate, voir, every, kang, pxe,
# Nearest to during: harmony, athene, rear, fanshawe, quickly, roda, battles, reign,
# Nearest to it: authoritarian, this, labienus, imf, body, debate, somalis, he,
# Nearest to would: could, will, might, should, jewishencyclopedia, must, had, works,
# Nearest to system: representation, byu, comprising, sefer, watterson, kurdish, central, behaviour,
# Nearest to united: vaccine, polymers, cassiodorus, undecidability, highland, air, wales, bequeathed,
# Nearest to liberal: republican, alliance, parties, fjords, support, recommended, arts, leaders,
# Nearest to primarily: charming, arquette, generally, albums, ashamed, fathoms, expanses, mainly,
# Nearest to http: collect, org, com, rag, www, stimulate, mp, xl,
# Nearest to orthodox: church, protestant, catholic, painter, gaim, fleet, ypsilanti, emergent,
# Nearest to san: class, kalarippayattu, span, electrophoresis, hollows, pl, clock, california,
# Nearest to ice: operations, mistake, off, tull, vasily, apologize, architectures, arkwright,
# Nearest to assembly: udon, marsyas, judicial, passau, lucien, intervention, receivers, choo,
# Nearest to bill: clinton, federation, shi, actor, expressed, operas, longitude, arch,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.0683 0.0741 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.0623 0.0733 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.0667 0.0737 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.0690 0.0735 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.0212 0.0734 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.0840 0.0735 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.0095 0.0738 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.0741 0.0738 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.0561 0.0736 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.0897 0.0734 sec/batch
# Nearest to from: popularised, online, provincial, autoconfiguration, satirizes, rivals, berets, gv,
# Nearest to is: means, superheroic, was, applies, avianca, ann, has, sweetness,
# Nearest to all: council, beings, communion, correlate, every, voir, display, kang,
# Nearest to during: harmony, athene, roda, battles, fanshawe, reign, later, batista,
# Nearest to it: authoritarian, this, imf, labienus, somalis, debate, body, he,
# Nearest to would: could, will, might, should, jewishencyclopedia, must, works, had,
# Nearest to system: representation, byu, comprising, kurdish, sefer, watterson, central, systems,
# Nearest to united: vaccine, polymers, cassiodorus, undecidability, highland, karachi, air, case,
# Nearest to liberal: republican, fjords, alliance, parties, roar, julia, arts, democrats,
# Nearest to primarily: charming, arquette, generally, fathoms, ashamed, mainly, albums, expanses,
# Nearest to http: collect, org, com, rag, www, stimulate, transit, external,
# Nearest to orthodox: church, painter, protestant, catholic, gaim, ypsilanti, fleet, churches,
# Nearest to san: class, kalarippayattu, span, electrophoresis, hollows, pl, clock, california,
# Nearest to ice: operations, tull, mistake, arkwright, off, architectures, genosha, vasily,
# Nearest to assembly: udon, marsyas, judicial, passau, lucien, process, receivers, choo,
# Nearest to bill: clinton, federation, actor, expressed, shi, arch, longitude, chose,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 3.9044 0.0739 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 3.7136 0.0732 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 3.8927 0.0731 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 3.9399 0.0745 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.0202 0.0742 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.0392 0.0739 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.0402 0.0735 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.0675 0.0735 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.0599 0.0734 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.0584 0.0736 sec/batch
# Nearest to from: popularised, online, provincial, autoconfiguration, georgia, gv, subgroup, berets,
# Nearest to is: means, superheroic, was, avianca, applies, has, ann, sweetness,
# Nearest to all: council, beings, correlate, communion, voir, every, kang, pxe,
# Nearest to during: harmony, athene, battles, rear, roda, batista, later, fanshawe,
# Nearest to it: authoritarian, this, imf, labienus, somalis, he, body, currents,
# Nearest to would: could, will, might, should, jewishencyclopedia, must, seemed, had,
# Nearest to system: representation, byu, sefer, watterson, central, kurdish, immunological, comprising,
# Nearest to united: vaccine, polymers, cassiodorus, case, undecidability, highland, bequeathed, wales,
# Nearest to liberal: republican, fjords, marx, julia, parties, alliance, arts, conservative,
# Nearest to primarily: charming, arquette, generally, fathoms, ashamed, albums, expanses, mainly,
# Nearest to http: collect, org, rag, com, www, stimulate, xl, annulment,
# Nearest to orthodox: church, painter, protestant, gaim, fleet, ypsilanti, catholic, churches,
# Nearest to san: class, kalarippayattu, span, electrophoresis, california, hollows, pl, courses,
# Nearest to ice: operations, mistake, arkwright, off, tull, architectures, friction, genosha,
# Nearest to assembly: udon, marsyas, judicial, passau, specified, receivers, lucien, bounty,
# Nearest to bill: clinton, federation, actor, shi, expressed, chose, longitude, convenience,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.0797 0.0742 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.0584 0.0734 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.0080 0.0734 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.0817 0.0736 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.0567 0.0737 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.0319 0.0733 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.0598 0.0736 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.0740 0.0733 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.0668 0.0716 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.0462 0.0716 sec/batch
# Nearest to from: popularised, online, provincial, autoconfiguration, rivals, satirizes, berets, nida,
# Nearest to is: means, superheroic, was, avianca, applies, ann, sweetness, has,
# Nearest to all: council, beings, correlate, voir, orbits, every, communion, pxe,
# Nearest to during: harmony, athene, battles, rear, roda, fanshawe, later, pyrrhic,
# Nearest to it: authoritarian, this, labienus, imf, somalis, he, body, currents,
# Nearest to would: could, might, will, should, jewishencyclopedia, must, works, seemed,
# Nearest to system: representation, byu, sefer, watterson, systems, central, kurdish, immunological,
# Nearest to united: vaccine, polymers, cassiodorus, undecidability, case, highland, karachi, air,
# ...
# Nearest to united: vaccine, polymers, disco, cassiodorus, benefits, undecidability, case, situation,
# Nearest to liberal: alliance, flutes, wessel, arts, studies, democrats, preferred, guardianship,
# Nearest to primarily: mainly, generally, typically, frequently, exclusively, arquette, widely, catalyst,
# Nearest to http: www, com, html, collect, org, rag, external, htm,
# Nearest to orthodox: painter, churches, fleet, gaim, harboring, ypsilanti, extant, editorials,
# Nearest to san: california, los, hollows, santa, francisco, florence, pl, span,
# Nearest to ice: arkwright, friction, fragments, drumming, centuriate, iie, bronze, quintilian,
# Nearest to assembly: oat, maryam, bounty, fran, chalcolithic, patagonia, allowing, marsyas,
# Nearest to bill: clinton, averages, actor, scandal, topol, szab, lakewood, hostility,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 3.9509 0.0733 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 4.0112 0.0719 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 4.0270 0.0730 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 4.0217 0.0723 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 4.0325 0.0732 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 4.0379 0.0746 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 4.0084 0.0724 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 4.0305 0.0722 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 3.9964 0.0731 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 4.0310 0.0726 sec/batch
# Nearest to from: popularised, in, nida, back, of, franciscan, gv, claiming,
# Nearest to is: was, are, has, refers, provides, makes, be, applies,
# Nearest to all: every, bungee, council, lyapunov, poststructuralist, various, many, property,
# Nearest to during: until, athene, throughout, charterers, frigate, post, era, in,
# Nearest to it: he, she, this, itself, similarly, potted, its, apron,
# Nearest to would: could, might, will, should, may, must, can, seemed,
# Nearest to system: systems, representation, rendering, central, basic, moon, simulations, tra,
# Nearest to united: vaccine, polymers, cassiodorus, disco, undecidability, situation, benefits, gilgal,
# Nearest to liberal: alliance, flutes, wessel, democrats, studies, hmmwv, arts, preferred,
# Nearest to primarily: mainly, generally, typically, arquette, widely, exclusively, frequently, fathoms,
# Nearest to http: www, com, html, collect, rag, external, htm, org,
# Nearest to orthodox: painter, churches, fleet, gaim, harboring, ypsilanti, extant, editorials,
# Nearest to san: california, hollows, los, francisco, santa, florence, pl, kalarippayattu,
# Nearest to ice: arkwright, fragments, friction, drumming, centuriate, bronze, iie, betamax,
# Nearest to assembly: oat, maryam, bounty, fran, marsyas, chalcolithic, patagonia, legislative,
# Nearest to bill: clinton, averages, actor, scandal, topol, hardin, hostility, lakewood,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 4.0322 0.0731 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 4.0117 0.0750 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 4.0327 0.0734 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 4.0323 0.0726 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.0286 0.0732 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.0281 0.0728 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 3.9636 0.0735 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 4.0146 0.0724 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 3.9584 0.0719 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.0408 0.0731 sec/batch
# Nearest to from: nida, back, popularised, in, franciscan, claiming, gv, of,
# Nearest to is: was, are, has, refers, makes, provides, be, applies,
# Nearest to all: every, council, bungee, lyapunov, poststructuralist, various, always, worship,
# Nearest to during: until, throughout, athene, era, charterers, frigate, post, in,
# Nearest to it: he, she, this, itself, similarly, potted, its, apron,
# Nearest to would: could, might, will, should, may, must, can, seemed,
# Nearest to system: systems, representation, rendering, central, basic, tra, simulations, moon,
# Nearest to united: vaccine, cassiodorus, disco, polymers, undecidability, situation, navy, gilgal,
# Nearest to liberal: alliance, studies, flutes, democrats, wessel, arts, guardianship, preferred,
# Nearest to primarily: mainly, generally, typically, arquette, exclusively, widely, enacted, microstates,
# Nearest to http: www, com, html, collect, rag, external, htm, org,
# Nearest to orthodox: churches, painter, fleet, gaim, harboring, ypsilanti, extant, church,
# Nearest to san: california, hollows, los, florence, santa, francisco, pl, kalarippayattu,
# Nearest to ice: arkwright, fragments, friction, drumming, centuriate, bronze, iie, betamax,
# Nearest to assembly: oat, maryam, bounty, fran, chalcolithic, museo, patagonia, marsyas,
# Nearest to bill: clinton, averages, actor, scandal, topol, lakewood, hardin, szab,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 4.0210 0.0743 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.0459 0.0750 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 3.9695 0.0801 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.0347 0.0836 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 4.0206 0.0856 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 4.0253 0.0731 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 4.0232 0.0732 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 4.0510 0.0723 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 4.0325 0.0729 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 4.0155 0.0728 sec/batch
# Nearest to from: in, popularised, nida, back, of, gv, multiples, claiming,
# Nearest to is: was, are, has, refers, makes, provides, means, applies,
# Nearest to all: every, lyapunov, council, various, poststructuralist, bungee, pxe, always,
# Nearest to during: until, athene, throughout, charterers, in, era, post, frigate,
# Nearest to it: he, she, this, itself, similarly, potted, its, apron,
# Nearest to would: could, might, will, should, may, must, seemed, can,
# Nearest to system: systems, representation, rendering, central, moon, basic, tra, loadable,
# Nearest to united: vaccine, cassiodorus, disco, polymers, navy, undecidability, representatives, gilgal,
# Nearest to liberal: alliance, studies, arts, flutes, wessel, democrats, guardianship, hmmwv,
# Nearest to primarily: mainly, generally, typically, arquette, exclusively, widely, frequently, microstates,
# Nearest to http: www, com, html, collect, htm, rag, org, external,
# Nearest to orthodox: painter, churches, fleet, gaim, harboring, ypsilanti, extant, dung,
# Nearest to san: california, hollows, santa, florence, los, francisco, pl, shortly,
# Nearest to ice: arkwright, fragments, friction, quintilian, betamax, iron, iie, bronze,
# Nearest to assembly: oat, maryam, bounty, fran, allowing, continuum, museo, chalcolithic,
# Nearest to bill: clinton, topol, scandal, lakewood, averages, actor, szab, bebe,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 4.0431 0.0741 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 4.0425 0.0813 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 4.0129 0.0751 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 4.0260 0.0749 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 4.0184 0.0739 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 4.0150 0.0725 sec/batch
# Epoch 10/10 Iteration: 116700 Avg. Training loss: 4.0176 0.0722 sec/batch
# Epoch 10/10 Iteration: 116800 Avg. Training loss: 4.0348 0.0734 sec/batch
# Epoch 10/10 Iteration: 116900 Avg. Training loss: 4.0006 0.0730 sec/batch
# Epoch 10/10 Iteration: 117000 Avg. Training loss: 4.0307 0.0739 sec/batch
# Nearest to from: popularised, in, nida, back, of, maintainers, retrieved, gv,
# Nearest to is: was, are, has, refers, provides, makes, be, means,
# Nearest to all: every, lyapunov, bungee, various, poststructuralist, council, always, except,
# Nearest to during: until, athene, charterers, throughout, in, era, ended, through,
# Nearest to it: he, she, this, itself, similarly, potted, apron, its,
# Nearest to would: could, might, will, should, may, must, can, seemed,
# Nearest to system: systems, rendering, central, representation, moon, basic, simulations, loadable,
# Nearest to united: vaccine, cassiodorus, disco, polymers, navy, representatives, duchenne, situation,
# Nearest to liberal: alliance, studies, flutes, arts, wessel, democrats, guardianship, preferred,
# Nearest to primarily: mainly, generally, typically, arquette, exclusively, widely, frequently, microstates,
# Nearest to http: www, com, html, collect, htm, website, external, n,
# Nearest to orthodox: painter, churches, fleet, harboring, gaim, ypsilanti, dung, extant,
# Nearest to san: california, hollows, santa, florence, los, francisco, pl, kalarippayattu,
# Nearest to ice: arkwright, friction, fragments, tull, centuriate, quintilian, architectures, iie,
# Nearest to assembly: oat, maryam, bounty, fran, museo, patagonia, allowing, chalcolithic,
# Nearest to bill: clinton, topol, averages, lakewood, piping, bebe, scandal, common,
# Epoch 10/10 Iteration: 117100 Avg. Training loss: 3.9625 0.0753 sec/batch
# Epoch 10/10 Iteration: 117200 Avg. Training loss: 4.0398 0.0779 sec/batch
# Epoch 10/10 Iteration: 117300 Avg. Training loss: 4.0068 0.0729 sec/batch
# Epoch 10/10 Iteration: 117400 Avg. Training loss: 4.0460 0.0722 sec/batch
# Epoch 10/10 Iteration: 117500 Avg. Training loss: 3.9411 0.0724 sec/batch
# Epoch 10/10 Iteration: 117600 Avg. Training loss: 3.6325 0.0767 sec/batch
# Epoch 10/10 Iteration: 117700 Avg. Training loss: 3.9050 0.0726 sec/batch
# Epoch 10/10 Iteration: 117800 Avg. Training loss: 3.8421 0.0749 sec/batch
# Epoch 10/10 Iteration: 117900 Avg. Training loss: 3.9692 0.0724 sec/batch
# Epoch 10/10 Iteration: 118000 Avg. Training loss: 3.9905 0.0764 sec/batch
# Nearest to from: in, back, of, popularised, multiples, nida, claiming, retrieved,
# Nearest to is: was, has, are, refers, provides, makes, be, means,
# Nearest to all: every, lyapunov, bungee, council, various, worship, poststructuralist, except,
# Nearest to during: until, athene, throughout, charterers, in, post, ended, era,
# Nearest to it: he, she, this, itself, similarly, potted, specifically, only,
# Nearest to would: could, might, will, should, may, must, seemed, can,
# Nearest to system: systems, central, rendering, representation, basic, moon, loadable, immunological,
# Nearest to united: disco, vaccine, representatives, cassiodorus, case, navy, polymers, undecidability,
# Nearest to liberal: alliance, flutes, wessel, democrats, studies, arts, preferred, conservative,
# Nearest to primarily: mainly, generally, typically, arquette, exclusively, microstates, frequently, widely,
# Nearest to http: www, com, html, htm, collect, website, rag, n,
# Nearest to orthodox: painter, churches, fleet, harboring, ypsilanti, dung, gaim, extant,
# Nearest to san: california, hollows, santa, francisco, florence, los, pl, kalarippayattu,
# Nearest to ice: arkwright, fragments, friction, betamax, quintilian, iron, iie, centuriate,
# Nearest to assembly: oat, maryam, bounty, fran, allowing, museo, patagonia, chalcolithic,
# Nearest to bill: clinton, topol, scandal, averages, bebe, hardin, lakewood, actor,
# Epoch 10/10 Iteration: 118100 Avg. Training loss: 4.0164 0.0765 sec/batch
# Epoch 10/10 Iteration: 118200 Avg. Training loss: 4.0150 0.0733 sec/batch
# Epoch 10/10 Iteration: 118300 Avg. Training loss: 4.0277 0.0755 sec/batch
# Epoch 10/10 Iteration: 118400 Avg. Training loss: 4.0269 0.0742 sec/batch
# Epoch 10/10 Iteration: 118500 Avg. Training loss: 4.0391 0.0741 sec/batch
# Epoch 10/10 Iteration: 118600 Avg. Training loss: 4.0225 0.0752 sec/batch
# Epoch 10/10 Iteration: 118700 Avg. Training loss: 3.9609 0.0773 sec/batch
# Epoch 10/10 Iteration: 118800 Avg. Training loss: 4.0344 0.0754 sec/batch
# Epoch 10/10 Iteration: 118900 Avg. Training loss: 4.0153 0.0758 sec/batch
# Epoch 10/10 Iteration: 119000 Avg. Training loss: 4.0053 0.0721 sec/batch
# Nearest to from: popularised, back, in, nida, of, gv, franciscan, foo,
# Nearest to is: was, are, has, refers, be, provides, makes, means,
# Nearest to all: every, lyapunov, bungee, poststructuralist, council, various, except, ceti,
# Nearest to during: until, athene, era, throughout, charterers, post, ended, frigate,
# Nearest to it: he, she, this, itself, similarly, its, potted, the,
# Nearest to would: could, might, will, should, may, must, seemed, can,
# Nearest to system: systems, central, representation, rendering, basic, moon, simulations, loadable,
# Nearest to united: disco, vaccine, cassiodorus, polymers, representatives, situation, navy, gilgal,
# Nearest to liberal: alliance, wessel, flutes, arts, democrats, studies, preferred, ilp,
# Nearest to primarily: mainly, generally, typically, arquette, exclusively, microstates, widely, frequently,
# Nearest to http: www, com, html, htm, collect, external, rag, org,
# Nearest to orthodox: painter, churches, fleet, harboring, gaim, ypsilanti, dung, extant,
# Nearest to san: california, santa, hollows, florence, francisco, los, pl, kalarippayattu,
# Nearest to ice: arkwright, friction, fragments, betamax, drumming, iie, centuriate, quintilian,
# Nearest to assembly: oat, maryam, bounty, fran, allowing, museo, patagonia, marsyas,
# Nearest to bill: clinton, topol, averages, scandal, gun, alagoas, lakewood, ert,
# Epoch 10/10 Iteration: 119100 Avg. Training loss: 4.0207 0.0752 sec/batch
# Epoch 10/10 Iteration: 119200 Avg. Training loss: 4.0392 0.0732 sec/batch
# Epoch 10/10 Iteration: 119300 Avg. Training loss: 4.0094 0.0740 sec/batch
# Epoch 10/10 Iteration: 119400 Avg. Training loss: 4.0178 0.0745 sec/batch
# Epoch 10/10 Iteration: 119500 Avg. Training loss: 3.8910 0.0923 sec/batch
# Epoch 10/10 Iteration: 119600 Avg. Training loss: 4.0116 0.0910 sec/batch
# Epoch 10/10 Iteration: 119700 Avg. Training loss: 4.0006 0.0775 sec/batch
# Epoch 10/10 Iteration: 119800 Avg. Training loss: 3.8970 0.0785 sec/batch
# Epoch 10/10 Iteration: 119900 Avg. Training loss: 4.0128 0.0787 sec/batch
# Epoch 10/10 Iteration: 120000 Avg. Training loss: 4.0316 0.0779 sec/batch
# Nearest to from: back, nida, popularised, in, of, online, gv, claiming,
# Nearest to is: was, are, has, refers, provides, makes, be, means,
# Nearest to all: every, lyapunov, bungee, poststructuralist, always, council, various, except,
# Nearest to during: athene, until, charterers, era, throughout, in, post, ended,
# Nearest to it: he, she, itself, this, similarly, its, potted, specifically,
# Nearest to would: could, might, will, should, may, must, seemed, can,
# Nearest to system: systems, central, rendering, representation, basic, epd, loadable, immunological,
# Nearest to united: disco, cassiodorus, vaccine, krestinsky, polymers, representatives, navy, gilgal,
# Nearest to liberal: alliance, arts, studies, flutes, wessel, democrats, guardianship, conservative,
# Nearest to primarily: mainly, generally, typically, exclusively, arquette, microstates, widely, frequently,
# Nearest to http: www, com, html, htm, collect, rag, n, org,
# Nearest to orthodox: painter, churches, harboring, fleet, gaim, extant, dung, ypsilanti,
# Nearest to san: california, hollows, santa, florence, francisco, los, pl, kalarippayattu,
# Nearest to ice: arkwright, friction, fragments, centuriate, drumming, tull, betamax, iie,
# Nearest to assembly: maryam, oat, bounty, museo, fran, patagonia, chalcolithic, allowing,
# Nearest to bill: clinton, topol, hardin, averages, gun, alagoas, bebe, taocp,
# Epoch 10/10 Iteration: 120100 Avg. Training loss: 4.0018 0.0781 sec/batch
# Epoch 10/10 Iteration: 120200 Avg. Training loss: 3.9819 0.0788 sec/batch
# Epoch 10/10 Iteration: 120300 Avg. Training loss: 3.9833 0.0775 sec/batch
# Epoch 10/10 Iteration: 120400 Avg. Training loss: 3.9930 0.0775 sec/batch
# Epoch 10/10 Iteration: 120500 Avg. Training loss: 4.0556 0.0756 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
